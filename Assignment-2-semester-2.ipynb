# %% [markdown]
# # Assignment Two

# %% [markdown]
# # Time Series Analysis of Daily Steps Data
#
# Author: **Kibuani Kodasso**
# Date: **13 August 2024**
# https://github.com/Kodasso/Assignment-2-semester-2.git

# %% [markdown]
# ### Importing dependencies

# %%
from IPython.display import display

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from sklearn.metrics import mean_squared_error, r2_score
register_matplotlib_converters()

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
#from statsmodels.tsa.arima.model.ARIMA import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from time import time
import seaborn as sns
sns.set(style='whitegrid')

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = np.random.seed(0)

# %% [markdown]
# Next we are going to import, clean, and plot the time series data

# %% [markdown]
# ### Step 1: The Data Preparation
# #### Extract-Transform-Load
# ##### First of all we need to combine all 15 csv files into one data frame

# %%
import pandas as pd

# List all CSV files in the directory
csv_files = ['Steps1.csv', 'Steps2.csv', 'Steps3.csv', 'Steps4.csv', 'Steps5.csv', 'Steps6.csv', 
             'Steps7.csv', 'Steps8.csv', 'Steps9.csv', 'Steps10.csv', 'Steps11.csv', 
             'Steps12.csv', 'Steps13.csv', 'Steps14.csv', 'Steps15.csv']

# Initialize an empty list to hold the DataFrames
data_frames = []

# Loop through each CSV file and append its data to the list
for file in csv_files:
    data = pd.read_csv(file)
    data_frames.append(data)

# Concatenate all DataFrames in the list into a single DataFrame
combined_fitness_data = pd.concat(data_frames, ignore_index=True)

# Save the combined DataFrame to a CSV file (uncomment the line below to save)
combined_fitness_data.to_csv('combined.csv', index=False)

# %% [markdown]
# #### Converting "Date" column to datetime format

# %%
combined_fitness_data["Date"] = pd.to_datetime(combined_fitness_data["Date"], format='mixed')

# %% [markdown]
# #### Set the index to the "Date" column

# %%
# Set the index to the "Date" column
combined_fitness_data.set_index("Date", inplace=True)

# %% [markdown]
# #### Handling missing values

# %%
# Fill missing values with the mean of the column
combined_fitness_data.fillna(combined_fitness_data.mean(), inplace=True)

# %% [markdown]
# <p> Now our data is called combined_fitness_data </p>

# %% [markdown]
# ### Let's view the data

# %%
combined_fitness_data.head()
# Out:
#             Actual  Goal
# Date
# 2022-05-31       0  8000
# 2022-06-01       0  8000
# 2022-06-02       0  8000
# 2022-06-03    1102  8000
# 2022-06-04    1254  8000

# %%
combined_fitness_data
# Out:
#             Actual  Goal
# Date
# 2022-05-31       0  8000
# 2022-06-01       0  8000
# 2022-06-02       0  8000
# 2022-06-03    1102  8000
# 2022-06-04    1254  8000
# ...            ...   ...
# 2023-07-20    8393  6500
# 2023-07-21    5954  6500
# 2023-07-22    9550  6500
# 2023-07-23    5157  6500
# 2023-07-24    8923  6500
#
# [420 rows x 2 columns]

# %%
combined_fitness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 420 entries, 2022-05-31 to 2023-07-24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Actual  420 non-null    int64
#  1   Goal    420 non-null    int64
# dtypes: int64(2)
# memory usage: 9.8 KB

# %%
combined_fitness_data.isnull().sum()
# Out:
# Actual    0
# Goal      0
# dtype: int64

# %% [markdown]
# <p>No missing values; the dataset is ready to be used for analysis.</p>

# %% [markdown]
# ### Step 2 : The Exploratory of Data Analysis (EDA)

# %% [markdown]
# #### Visualizing the time series data

# %%
# Visualize time series
plt.figure(figsize=(14, 4))
plt.plot(combined_fitness_data["Actual"], label="Steps")
plt.title("Daily Steps Over Time", fontsize=20)
plt.xlabel("Date", fontsize=16)
plt.ylabel("Steps", fontsize=16)
plt.legend()
plt.show()

# %% [markdown]
# <p> First impressions, there is a definite trend and seasonality in the data </p>

# %% [markdown]
# #### Calculating descriptive statistics

# %%
# Calculate descriptive statistics
mean_steps = combined_fitness_data["Actual"].mean()
median_steps = combined_fitness_data["Actual"].median()
std_steps = combined_fitness_data["Actual"].std()
print("Mean:", mean_steps)
print("Median:", median_steps)
print("Standard Deviation:", std_steps)
# Out:
# Mean: 5674.140476190476
# Median: 5402.0
# Standard Deviation: 2930.565438900008

# %%
combined_fitness_data["Actual"].describe()
# Out:
# count      420.000000
# mean      5674.140476
# std       2930.565439
# min          0.000000
# 25%       3634.000000
# 50%       5402.000000
# 75%       7349.000000
# max      16611.000000
# Name: Actual, dtype: float64

# %% [markdown]
# ###  Step 3: Test for seasonality and if the data is stationary

# %% [markdown]
# #### Let's do STL decomposition

# %%
plt.rc('figure',figsize=(14,8))
plt.rc('font', size = 15)
# Perform seasonal decomposition
result = seasonal_decompose(combined_fitness_data['Actual'], model='additive')

# Plot decomposed components
fig = result.plot()

# %% [markdown]
# #### Points to consider
#
# <p>1. There is a visible 7 days seasonal pattern <br>
# 2. The trend is evidently fluactuating </p>

# %% [markdown]
# #### Performing Augmented Dickey-Fuller test

# %%
#Perform Dickey-fuller test

print("Results of Dickey-Fuller Test:")
dftest = adfuller(combined_fitness_data["Actual"], autolag = 'AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observation Used'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.831054
# p-value                         0.000047
# #Lags Used                     13.000000
# Number of Observation Used    406.000000
# Critical Value (1%)            -3.446560
# Critical Value (5%)            -2.868685
# Critical Value (10%)           -2.570576
# dtype: float64

# %% [markdown]
# <p>Based on these results, it seems that the time series data is <b>stationary</b>, since the ADF statistic is -4.83 and the p-value is  0.000047 (very close to zero). This is an important consideration for many time series analyses and forecasting techniques, as they often assume to work better with stationary data.</p>

# %% [markdown]
# ### Step 4: Model selection

# %%
from IPython.display import display, HTML

display(HTML("<p>Since the time series data is stationary, ARIMA is the model to start with to fit the prediction.</p>"))
print("Since the time series data is stationary, ARIMA is the model to start with for fitting the prediction.")
# Out:
# <p>Since the time series data is stationary, ARIMA is the model to start with to fit the prediction.</p>
# Since the time series data is stationary, ARIMA is the model to start with for fitting the prediction.

# %% [markdown]
# #### ACF and PACF plots to estimate p and q value

# %%
#ACF and PACF plots:

lag_acf = acf(combined_fitness_data["Actual"], nlags = 20)
lag_pacf = pacf(combined_fitness_data["Actual"], nlags = 20, method ='ols')

#Plot ACF: for the value of q
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(combined_fitness_data["Actual"])), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(combined_fitness_data["Actual"])), linestyle='--', color='gray')
plt.title("Autocorrelation Function")


#Plot PACF: for the value of p
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(combined_fitness_data["Actual"])), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(combined_fitness_data["Actual"])), linestyle='--', color='gray')
plt.title("Partial Autocorrelation Function")

plt.tight_layout()

# %%
# Plot ACF
plt.figure(figsize=(12, 6))
plot_acf(combined_fitness_data["Actual"], lags=30, alpha=0.05)
plt.title("ACF (AutoCorrelation Function)")
plt.xlabel("Lags")
plt.ylabel("ACF Value")
plt.show()

# Plot PACF
plt.figure(figsize=(12, 6))
plot_pacf(combined_fitness_data["Actual"], lags=30, alpha=0.05)
plt.title("PACF (Partial AutoCorrelation Function)")
plt.xlabel("Lags")
plt.ylabel("PACF Value")
plt.show()

# %%
print("The value of q can be 1, 2, 3, and 4.\nThe value of p can be 1, 2, and 3.")
# Out:
# The value of q can be 1, 2, 3, and 4.
# The value of p can be 1, 2, and 3.

# %% [markdown]
# #### Fitting ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA
p = 2  # Specify the order of the auto-regressive component
d = 0  # Since the data is stationary, no differencing is needed
q = 4  # Specify the order of the moving average component

arima_model = ARIMA(combined_fitness_data["Actual"], order=(p, d, q))
arima_model_fit = arima_model.fit()

# Print model summary
print(arima_model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Actual   No. Observations:                  420
# Model:                 ARIMA(2, 0, 4)   Log Likelihood               -3923.903
# Date:                Sat, 10 Aug 2024   AIC                           7863.806
# Time:                        16:37:34   BIC                           7896.128
# Sample:                    05-31-2022   HQIC                          7876.581
#                          - 07-24-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5674.1396    196.417     28.888      0.000    5289.169    6059.110
# ar.L1         -0.4498      0.006    -69.315      0.000      -0.463      -0.437
# ar.L2         -0.9996      0.002   -415.205      0.000      -1.004      -0.995
# ma.L1          0.6219      0.051     12.204      0.000       0.522       0.722
# ma.L2          1.2540      0.075     16.741      0.000       1.107       1.401
# ma.L3          0.2473      0.057      4.372      0.000       0.136       0.358
# ma.L4          0.1810      0.044      4.103      0.000       0.095       0.267
# sigma2      7.774e+06      0.015   5.12e+08      0.000    7.77e+06    7.77e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                29.35
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             0.57
# Prob(H) (two-sided):                  0.49   Kurtosis:                         3.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.05e+23. Standard errors may be unstable.

# %%
plt.plot(combined_fitness_data["Actual"])
plt.plot(arima_model_fit.fittedvalues, color='red')
plt.title('RSS: %.4f' % sum((arima_model_fit.fittedvalues - combined_fitness_data["Actual"]) **2))
print("plotting MA model")
# Out:
# plotting MA model

# %%
print("The model struggled to fit at the beginning, but it managed to catch the curves well at the end.")
# Out:
# The model struggled to fit at the beginning, but it managed to catch the curves well at the end.

# %% [markdown]
# ### Step 5: Forcasting

# %%
# Define forecasting start date
forecast_start = datetime(2023, 6, 25)


forecast_length = 120
# Forecast steps
forecast_steps = arima_model_fit.get_forecast(steps=forecast_length) 
forecast_index = pd.date_range(forecast_start, periods=forecast_length)

# Plot actual vs. forecasted steps
plt.figure(figsize=(12, 6))
plt.plot(combined_fitness_data["Actual"].index, combined_fitness_data["Actual"], label="Actual Steps")
plt.plot(forecast_index, forecast_steps.predicted_mean, label="Forecasted Steps", color="red")
plt.title("Actual vs. Forecasted Daily Steps")
plt.xlabel("Date")
plt.ylabel("Steps")
plt.legend()
plt.show()

# %%
from IPython.display import display, HTML

display(HTML("<p>Eureka, we have done it, we predicted the number of steps.</p>"))
# Out:
# <p>Eureka, we have done it, we predicted the number of steps.</p>

# %% [markdown]
# #### Another way of predicting

# %%
predictions = arima_model.fit().predict()

plt.figure(figsize=(16,4))
plt.plot(combined_fitness_data['Actual'], label ='Actual Steps')
plt.plot(predictions, label='Predicted Steps')
plt.title('Comparaison of actual steps vs predicted steps', fontsize=20)
plt.ylabel('Steps', fontsize=16)
plt.legend()

# %%
print("This model just fits perfectly.")
# Out:
# This model just fits perfectly.

# %%
train_size = int(len(combined_fitness_data['Actual']) * 0.8)
train_data, test_data = combined_fitness_data['Actual'][:train_size], combined_fitness_data['Actual'][train_size:]

# %%
forecasts = arima_model_fit.forecast(steps=len(test_data))

# %%
#Calculating the mean squared error and the rsquared
mse = mean_squared_error(test_data, forecasts)
r2 = r2_score(test_data, forecasts)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 5823311.692488462
# R-squared: 0.05387880689129987

# %%
plt.plot(test_data, label='Actual')
plt.plot(forecasts, label='Forecasted')
plt.legend()
plt.title('Actual vs Forecasted Steps')
plt.show()

# %% [markdown]
# ### Fitting SARIMA to account for seasonality

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Define orders
seasonal_order = (2, 0, 4, 7) 
order = (2, 0, 4)

# Fit SARIMAX model
sarima_model = SARIMAX(combined_fitness_data["Actual"], order=order, seasonal_order=seasonal_order)
sarima_model_fit = sarima_model.fit(disp=0)

# Print model summary
print(sarima_model_fit.summary())
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                            Actual   No. Observations:                  420
# Model:             SARIMAX(2, 0, 4)x(2, 0, 4, 7)   Log Likelihood               -3911.819
# Date:                           Sat, 10 Aug 2024   AIC                           7849.638
# Time:                                   16:37:55   BIC                           7902.161
# Sample:                               05-31-2022   HQIC                          7870.398
#                                     - 07-24-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6390      0.789      2.077      0.038       0.092       3.186
# ar.L2         -0.6504      0.753     -0.864      0.387      -2.125       0.825
# ma.L1         -1.4615      0.787     -1.857      0.063      -3.004       0.081
# ma.L2          0.5802      0.598      0.970      0.332      -0.593       1.753
# ma.L3         -0.0446      0.112     -0.397      0.691      -0.264       0.175
# ma.L4         -0.0132      0.086     -0.154      0.877      -0.181       0.154
# ar.S.L7        1.4987      0.475      3.154      0.002       0.567       2.430
# ar.S.L14      -0.5063      0.463     -1.093      0.274      -1.414       0.402
# ma.S.L7       -1.3928      0.479     -2.905      0.004      -2.333      -0.453
# ma.S.L14       0.3860      0.428      0.902      0.367      -0.453       1.225
# ma.S.L21       0.1746      0.103      1.689      0.091      -0.028       0.377
# ma.S.L28      -0.1209      0.062     -1.957      0.050      -0.242       0.000
# sigma2      8.408e+06   6.84e-07   1.23e+13      0.000    8.41e+06    8.41e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                16.19
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             0.44
# Prob(H) (two-sided):                  0.59   Kurtosis:                         3.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.78e+28. Standard errors may be unstable.

# %%
plt.plot(combined_fitness_data["Actual"])
plt.plot(sarima_model_fit.fittedvalues, color='red')
plt.title('RSS: %.4f' % sum((sarima_model_fit.fittedvalues - combined_fitness_data["Actual"]) **2))
print("plotting SARIMA model")
# Out:
# plotting SARIMA model

# %% [markdown]
# #### Predicting

# %%
# Define forecasting start date
forecast_start = datetime(2023, 6, 25)
forecast_length = 120

# Forecast steps
forecast_steps = sarima_model_fit.get_forecast(steps=forecast_length) 
forecast_index = pd.date_range(forecast_start, periods=forecast_length)

sarima_forecasts = sarima_model_fit.get_forecast(steps=len(test_data))

# Plot actual vs. forecasted steps
plt.figure(figsize=(12, 6))
plt.plot(combined_fitness_data["Actual"].index, combined_fitness_data["Actual"], label="Actual Steps")
plt.plot(forecast_index, forecast_steps.predicted_mean, label="Forecasted Steps", color="red")
plt.title("Actual vs. Forecasted Daily Steps")
plt.xlabel("Date")
plt.ylabel("Steps")
plt.legend()
plt.show()



mse = mean_squared_error(test_data, sarima_forecasts.predicted_mean)
r2 = r2_score(test_data, sarima_forecasts.predicted_mean)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 6284727.976541532
# R-squared (R2): -0.021088110258471016

# %% [markdown]
# ### Step 6 : The Reflection

# %% [markdown]
# **Decision-Making Process:**
#
# 1. **Checking Stationarity:**
#    My decision process was mainly influenced by the time series data. After checking for stationarity, I found that the data is stationary.
#
# 2. **Choice of ARIMA:**
#    I first chose ARIMA, even though the data has a seasonal component. Surprisingly, the model fit well and was able to predict with a good RSS. However, the RSS was still high above 0.
#
# 3. **Choice of SARIMA:**
#    I then opted for a Seasonal ARIMA (SARIMA) model because the data has a seasonal component (steps could vary with the time of year), and SARIMA is well-suited for such data.
#
# 4. **Data Splitting:**
#    I split the data into training and testing sets to ensure the model's performance is evaluated on unseen data.
#
# 5. **Model Parameter Selection:**
#    I selected ARIMA orders (p, d, q) based on ACF and PACF, and SARIMA orders (p, d, q, P, D, Q, s) based on domain knowledge or experimentation, aiming for the best balance of accuracy and model complexity.
#
# 6. **Metric Selection:**
#    I chose Mean Squared Error (MSE) and R-squared to evaluate the model's forecasting accuracy, as they are common metrics for regression tasks.
#
# 7. **Visualization:**
#    I visualized the actual vs. forecasted data with confidence intervals to gain insights into the model's performance.
#
# **What I Learned:**
#
# 1. **Seasonal Trends:**
#    The data likely exhibits seasonal trends, possibly due to changes in physical activity throughout the year.
#
# 2. **Model Performance:**
#    I learned how well the SARIMA model could capture these seasonal trends and provide reasonably accurate forecasts. Additionally, I was impressed by the way the ARIMA model predicted the data.
#
# 3. **Metrics:**
#    MSE and R-squared provided a quantitative measure of model accuracy, and visualizations helped in qualitative assessment.
#
# 4. **Model Parameters:**
#    I learned that the order values greatly influence the model's performance.
#
# **What to Do Differently Next Time:**
#
# 1. **Hyperparameter Tuning:**
#    I would perform more extensive hyperparameter tuning to find the best ARIMA and SARIMA orders and seasonal orders.
#
# 2. **Data Preprocessing:**
#    Depending on the dataset, I might apply more advanced data preprocessing techniques, such as differencing or handling outliers.
#
# 3. **Model Comparison:**
#    In addition to ARIMA and SARIMA, I would consider testing other time series forecasting models, such as Prophet or Exponential Smoothing, to identify the best-performing model.
